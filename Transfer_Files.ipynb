# %%
import http.server
import socketserver
PORT = 8000
handler = http.server.SimpleHTTPRequestHandler
with socketserver.TCPServer(("", PORT), handler) as http:
    print("Server is running on port", PORT)
    http.serve_forever()
# Out:
# Server is running on port 8000
# 172.16.221.250 - - [26/Nov/2025 22:56:37] "GET / HTTP/1.1" 200 -
# 172.16.221.250 - - [26/Nov/2025 22:56:37] code 404, message File not found
# 172.16.221.250 - - [26/Nov/2025 22:56:37] "GET /favicon.ico HTTP/1.1" 404 -
